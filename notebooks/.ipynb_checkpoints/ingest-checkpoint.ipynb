# %%
import sys
sys.path.append("../src/")  # Agrega el directorio src al path

# %%
import os
DOCUMENTS_PATH = os.path.abspath("../data")
DOCUMENTS_PATH
# Out:
# 'c:\\Users\\Usuario\\Desktop\\RyP_4Pv3_Actividad_Laboratorio_Código_para_estudiantes\\legal-rag-comparison\\data'

# %%
pdfs = [file for file in os.listdir(DOCUMENTS_PATH) if file.endswith(".pdf") or file.endswith(".PDF")]

print(f"Número de documentos en la carpeta '{DOCUMENTS_PATH}': {len(pdfs)}")
# Out:
# Número de documentos en la carpeta 'c:\Users\Usuario\Desktop\RyP_4Pv3_Actividad_Laboratorio_Código_para_estudiantes\legal-rag-comparison\data': 30

# %% [markdown]
# Choose parser and chunker:

# %%
from parser import PDFParser
from chunking import PDFChunker

parser = PDFParser()
chunker = PDFChunker()

# %% [markdown]
# Iterate over all docs:

# %%
from tqdm import tqdm

chunks = []
for pdf in tqdm(pdfs, desc="Parseing and chunking PDFs"):
    file_path = os.path.join(DOCUMENTS_PATH, pdf)

    # Parsear el PDF
    file_documents = parser.parse(file_path)
    
    # Chunking de los documentos
    file_chunks = chunker.chunk(file_documents)

    chunks.extend(file_chunks)
    
print(f"Número total de chunks generados para todos los documentos: {len(chunks)}")
# Out:
# Parseing and chunking PDFs: 100%|██████████| 30/30 [02:46<00:00,  5.57s/it]
# Número total de chunks generados para todos los documentos: 2571

# %%
display(type(chunks[0]))
display(chunks[0].metadata)
display(chunks[0].page_content[0:200])

display(chunks[5].metadata)
display(chunks[5].page_content[0:200])
# Out:
# langchain_core.documents.base.Document
# {'producer': 'Apache FOP Version 1.0',
#  'creator': 'Apache FOP Version 1.0',
#  'creationdate': '2026-04-21T19:41:28+02:00',
#  'source': 'c:\\Users\\Usuario\\Desktop\\RyP_4Pv3_Actividad_Laboratorio_Código_para_estudiantes\\legal-rag-comparison\\data\\ANM2026_197.pdf',
#  'total_pages': 241,
#  'page': 0,
#  'page_label': '1'}
# '1\nOrdenanzas municipales\nOrdenanza de Movilidad Sostenible, de 5 de octubre de 2018\nVersión: Última actualización publicada el 06/04/2026\nIdentificador:  ANM 2026\\197\nTipo de Disposición: Ordenanzas m'
# {'producer': 'Apache FOP Version 1.0',
#  'creator': 'Apache FOP Version 1.0',
#  'creationdate': '2026-04-21T19:41:28+02:00',
#  'source': 'c:\\Users\\Usuario\\Desktop\\RyP_4Pv3_Actividad_Laboratorio_Código_para_estudiantes\\legal-rag-comparison\\data\\ANM2026_197.pdf',
#  'total_pages': 241,
#  'page': 5,
#  'page_label': '6'}
# '6\nEl Libro cuarto, titulado "Disciplina viaria" consta de un único título, dividido a su vez en dos capítulos, destinados a\nregular las medidas provisionales como la inmovilización y retirada de vehíc'

# %% [markdown]
# Ingest documents:

# %%
from time import time
from embedding import HuggingFaceEmbeddingsLC

embedder = HuggingFaceEmbeddingsLC()

# ingest all chunks and preserve metadata
start_time = time()
embeddings = embedder.embed_documents([chunk.page_content for chunk in chunks])
end_time = time()
print(f"Tiempo total para generar embeddings: {end_time - start_time:.2f} segundos")

# Combine embeddings with metadata
embedded_chunks = []
for chunk, embedding in zip(chunks, embeddings):
    embedded_chunk = {
        "embedding": embedding,
        "metadata": chunk.metadata,
        "page_content": chunk.page_content
    }
    embedded_chunks.append(embedded_chunk)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 from time import time
# ----> 2 from embedding import HuggingFaceEmbeddingsLC
#       3
#       4 embedder = HuggingFaceEmbeddingsLC()
#       5
#
# File c:\Users\Usuario\Desktop\RyP_4Pv3_Actividad_Laboratorio_Código_para_estudiantes\legal-rag-comparison\notebooks\../src\embedding.py:1
# ----> 1 from langchain_huggingface import HuggingFaceEmbeddings
#       2 import torch
#       4 class HuggingFaceEmbeddingsLC:
#
# ModuleNotFoundError: No module named 'langchain_huggingface'
